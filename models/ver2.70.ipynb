# %% [markdown]
# Successfully running

# %%
(1)
# Data Processing and Visualization
import os
import random
import glob
import re

# Data Manipulation and Analysis
import numpy as np
import pandas as pd
import math

# Image Processing and Visualization
import matplotlib.pyplot as plt
import cv2
from skimage import io
from PIL import Image

# Deep Learning Framework (TensorFlow/Keras)
import tensorflow as tf
from tensorflow.keras.layers import (
    Conv2D, BatchNormalization, Activation, Conv2DTranspose, Concatenate, Input
)
from tensorflow.keras.models import Model

# Specific TensorFlow/Keras Components
from tensorflow.keras import layers, optimizers
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import (
    ReduceLROnPlateau, 
    EarlyStopping, 
    ModelCheckpoint, 
    LearningRateScheduler
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.losses import categorical_crossentropy
import tensorflow.keras.backend as K

# Other Libraries
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler, normalize
from IPython.display import display
from tensorflow.keras.models import load_model
from tensorflow.keras.losses import binary_crossentropy

# %% [markdown]
# Datamap imports the path of images and store them to a variable

# %%
(2)
datamap = []

# Specify the path to your dataset on your Windows machine
dataset_path = "Dataset_MRI"

# Iterate over subdirectories in the specified path
for sub_dir_path in glob.glob(dataset_path + "/*"):
    # Check if the current path is a directory
    if os.path.isdir(sub_dir_path):
        # Extract the tumor type from the directory name
        dir_name = os.path.basename(sub_dir_path)

        # Iterate over files in the directory
        for filename in os.listdir(sub_dir_path):
            # Construct the full path to the image file
            image_path = os.path.join(sub_dir_path, filename)
            
            # Load the image as an array
            image = cv2.imread(image_path, cv2.IMREAD_COLOR)
            
            # Check if the image is successfully loaded
            if image is not None:
                # Append a dictionary to the datamap
                datamap.append({
                    'tumor_type': dir_name,
                    'file_name': filename,
                    'file_path': image_path,  # Include the full file path
                    'image': image
                })

# Display the datamap
for entry in datamap[:10]:  # Display only the first 10 entries
    print(f"Tumor Type: {entry['tumor_type']}, File Name: {entry['file_name']}, File Path: {entry['file_path']}, Image Shape: {entry['image'].shape}")
# Out:
# Tumor Type: Gliomas, File Name: TCGA_CS_4941_19960909_11.tif, File Path: Dataset_MRI\Gliomas\TCGA_CS_4941_19960909_11.tif, Image Shape: (256, 256, 3)
# Tumor Type: Gliomas, File Name: TCGA_CS_4941_19960909_12.tif, File Path: Dataset_MRI\Gliomas\TCGA_CS_4941_19960909_12.tif, Image Shape: (256, 256, 3)
# Tumor Type: Gliomas, File Name: TCGA_CS_4941_19960909_13.tif, File Path: Dataset_MRI\Gliomas\TCGA_CS_4941_19960909_13.tif, Image Shape: (256, 256, 3)
# Tumor Type: Gliomas, File Name: TCGA_CS_4941_19960909_14.tif, File Path: Dataset_MRI\Gliomas\TCGA_CS_4941_19960909_14.tif, Image Shape: (256, 256, 3)
# Tumor Type: Gliomas, File Name: TCGA_CS_4941_19960909_15.tif, File Path: Dataset_MRI\Gliomas\TCGA_CS_4941_19960909_15.tif, Image Shape: (256, 256, 3)
# Tumor Type: Gliomas, File Name: TCGA_CS_4941_19960909_16.tif, File Path: Dataset_MRI\Gliomas\TCGA_CS_4941_19960909_16.tif, Image Shape: (256, 256, 3)
# Tumor Type: Gliomas, File Name: TCGA_CS_4942_19970222_10.tif, File Path: Dataset_MRI\Gliomas\TCGA_CS_4942_19970222_10.tif, Image Shape: (256, 256, 3)
# Tumor Type: Gliomas, File Name: TCGA_CS_4942_19970222_11.tif, File Path: Dataset_MRI\Gliomas\TCGA_CS_4942_19970222_11.tif, Image Shape: (256, 256, 3)
# Tumor Type: Gliomas, File Name: TCGA_CS_4942_19970222_12.tif, File Path: Dataset_MRI\Gliomas\TCGA_CS_4942_19970222_12.tif, Image Shape: (256, 256, 3)
# Tumor Type: Gliomas, File Name: TCGA_CS_4942_19970222_13.tif, File Path: Dataset_MRI\Gliomas\TCGA_CS_4942_19970222_13.tif, Image Shape: (256, 256, 3)

# %% [markdown]
# Coverting the datamap to dataframe

# %%
(3)
# Convert the data_map to a pandas DataFrame
datamap_df = pd.DataFrame(datamap)

# Display the first few rows of the DataFrame to verify its structure
print(datamap_df.head())
# print(df)
# Out:
#   tumor_type                     file_name  \
# 0    Gliomas  TCGA_CS_4941_19960909_11.tif
# 1    Gliomas  TCGA_CS_4941_19960909_12.tif
# 2    Gliomas  TCGA_CS_4941_19960909_13.tif
# 3    Gliomas  TCGA_CS_4941_19960909_14.tif
# 4    Gliomas  TCGA_CS_4941_19960909_15.tif
#
#                                           file_path  \
# 0  Dataset_MRI\Gliomas\TCGA_CS_4941_19960909_11.tif
# 1  Dataset_MRI\Gliomas\TCGA_CS_4941_19960909_12.tif
# 2  Dataset_MRI\Gliomas\TCGA_CS_4941_19960909_13.tif
# 3  Dataset_MRI\Gliomas\TCGA_CS_4941_19960909_14.tif
# 4  Dataset_MRI\Gliomas\TCGA_CS_4941_19960909_15.tif
#
#                                                image
# 0  [[[1, 1, 0], [1, 1, 0], [2, 2, 0], [2, 2, 0], ...
# 1  [[[1, 4, 0], [2, 2, 0], [3, 2, 0], [2, 4, 0], ...
# 2  [[[2, 3, 0], [3, 1, 0], [2, 2, 0], [1, 3, 0], ...
# 3  [[[1, 2, 0], [1, 2, 0], [1, 4, 0], [1, 4, 0], ...
# 4  [[[1, 5, 0], [2, 5, 0], [2, 4, 0], [2, 6, 0], ...

# %% [markdown]
# Displaying the images before pre-processing

# %%
(4)
# Fixed number of images to display and columns
num_images_to_display = 9
num_cols = 3
num_rows = 3  # Since num_images_to_display is 9 and num_cols is 3

# Create a new figure with subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 12))

# Select random rows from the DataFrame
random_rows = datamap_df.sample(n=num_images_to_display)

# Iterate through the randomly selected rows to display images
for idx, (index, row) in enumerate(random_rows.iterrows()):
    # Determine the current row and column for the subplot
    current_row, current_col = divmod(idx, num_cols)

    # Load and display the image
    img = Image.open(row['file_path'])
    axes[current_row, current_col].imshow(img)
    axes[current_row, current_col].set_title(row['file_name'])
    axes[current_row, current_col].axis('off')

# Hide any empty subplots if necessary
for i in range(idx + 1, num_rows * num_cols):
    axes[i // num_cols, i % num_cols].axis('off')

# Adjust subplot spacing and display the figure
plt.subplots_adjust(wspace=0.3, hspace=0.5)
plt.show()

# %% [markdown]
# Split data into training, testing, validation

# %%
(5)
# Import necessary libraries for splitting data
from sklearn.model_selection import train_test_split
import pandas as pd

# Split your data into training and validation sets
train_df, val_df = train_test_split(datamap_df, test_size=0.2, random_state=42)

# Ensure file paths are strings
train_df['file_path'] = train_df['file_path'].astype(str)
val_df['file_path'] = val_df['file_path'].astype(str)

# train_df and val_df are now ready for use
print("Size of train_df:", len(train_df))
print("Size of val_df:", len(val_df))

# Tumor type labels mapping
tumor_labels = {
    'no_tumor': 0,
    'Gliomas': 1,
    'Meningiomas': 2,
    'Pituitary_Tumor': 3,
    'Astrocytoma': 4,
    'Glioblastoma': 5,
    'Tumor_Type_6': 6
}

# Apply tumor type labels to the DataFrame
train_df['encoded_labels'] = train_df['tumor_type'].map(tumor_labels)
val_df['encoded_labels'] = val_df['tumor_type'].map(tumor_labels)
# Out:
# Size of train_df: 14
# Size of val_df: 4

# %%
(6)
# Instantiate a LabelEncoder
label_encoder = LabelEncoder()

#Apply tumor type labels to the DataFrame
train_df['encoded_labels'] = train_df['tumor_type'].map(tumor_labels)
val_df['encoded_labels'] = val_df['tumor_type'].map(tumor_labels)

# Fit and transform the labels in the training set
train_df['encoded_labels'] = label_encoder.fit_transform(train_df['tumor_type'])

# Transform the labels in the validation set
val_df['encoded_labels'] = label_encoder.transform(val_df['tumor_type'])

# %%
train_image_paths = train_df['file_path'].tolist()
train_labels = train_df['encoded_labels'].tolist()

val_image_paths = val_df['file_path'].tolist()
val_labels = val_df['encoded_labels'].tolist()

# %% [markdown]
# Data Generator

# %%
(7)
class CustomDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, image_paths, labels, batch_size, image_size, num_classes, augmenter=None, shuffle=True):
        self.image_paths = image_paths
        self.labels = labels
        self.batch_size = batch_size
        self.image_size = image_size
        self.num_classes = num_classes
        self.augmenter = augmenter  # For image augmentation
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.image_paths) / self.batch_size))

    def __getitem__(self, index):
        batch_indices = self.indexes[index * self.batch_size:(index + 1) * self.batch_size]
        batch_image_paths = [self.image_paths[k] for k in batch_indices]
        batch_labels = [self.labels[k] for k in batch_indices]
        X, y = self.__generate_Xy(batch_image_paths, batch_labels)
        return X, y

    def on_epoch_end(self):
        self.indexes = np.arange(len(self.image_paths))
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __generate_Xy(self, batch_image_paths, batch_labels):
        X = np.empty((self.batch_size, *self.image_size, 3))
        y = np.empty((self.batch_size, *self.image_size, self.num_classes))

        for i, (path, label) in enumerate(zip(batch_image_paths, batch_labels)):
            image = cv2.imread(path)

            # Ensure the image has 3 channels (convert grayscale to RGB if needed)
            if len(image.shape) == 2 or image.shape[2] == 1:
                image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

            # Resize the image to the specified size
            image = cv2.resize(image, self.image_size)
            X[i,] = image / 255.0

            label_matrix = np.zeros((*self.image_size, self.num_classes))
            label_matrix[:, :, int(label)] = 1  # Convert label to categorical
            y[i,] = label_matrix

        return X, y

    def preprocess_image(self, image):
        # Check if the image is grayscale (single channel)
        if len(image.shape) == 2 or image.shape[2] == 1:
            # Convert grayscale to RGB by duplicating the channel
            image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
        else:
            # Assuming the image is already in RGB
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        # Apply OTSU's thresholding
        thresholded = apply_otsus_thresholding(image)

        # Resizing
        resized = resize_image(thresholded, self.image_size)

        # Image Augmentation (if augmenter is provided)
        if self.augmenter:
            resized = self.augmenter(resized)

        # Image Normalization
        normalized = resized / 255.0

        return normalized

# Helper preprocessing functions (add or modify as needed)
def apply_otsus_thresholding(image):
    # Convert to grayscale for thresholding
    grayscale = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    _, thresholded = cv2.threshold(grayscale, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    return thresholded

def resize_image(image, size=(256, 256)):
    return cv2.resize(image, size)

# Parameters for the data generator
batch_size = 32  # Example batch size, adjust as needed
image_size = (256, 256)  # Target image size as per the model input
num_classes = 7  # Adjust based on the number of tumor types or categories

# Instantiate the custom data generators
# Instantiate the custom data generators with encoded labels
train_generator = CustomDataGenerator(
    image_paths=train_df['file_path'].tolist(),
    labels=train_df['encoded_labels'].tolist(),  # Use encoded labels
    batch_size=batch_size,
    image_size=image_size,
    num_classes=num_classes,
    shuffle=True
)

val_generator = CustomDataGenerator(
    image_paths=val_df['file_path'].tolist(),
    labels=val_df['encoded_labels'].tolist(),  # Use encoded labels
    batch_size=batch_size,
    image_size=image_size,
    num_classes=num_classes,
    shuffle=False
)

# %% [markdown]
# Train-Data & Validation-Data

# %%
(9)
# Custom VGG16 Encoder
def custom_vgg16_encoder(input_tensor):
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(input_tensor)
    x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = layers.MaxPooling2D((2, 2), strides=(2, 2))(x)

    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = layers.MaxPooling2D((2, 2), strides=(2, 2))(x)

    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    s1 = x  # Save the feature map for decoder
    x = layers.MaxPooling2D((2, 2), strides=(2, 2))(x)

    x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
    x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
    x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
    s2 = x  # Save the feature map for decoder
    x = layers.MaxPooling2D((2, 2), strides=(2, 2))(x)

    x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
    x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
    x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
    s3 = x  # Save the feature map for decoder

    return s3, s2, s1

# Custom U-Net Decoder
def custom_unet_decoder(conv4, conv3, conv2, conv1):
    # Decoder
    u6 = layers.Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(conv4)
    u6 = layers.concatenate([u6, conv3], axis=-1)
    u6 = layers.BatchNormalization()(u6)
    u6 = layers.Activation('relu')(u6)
    u6 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(u6)
    u6 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(u6)
    u6 = layers.Dropout(0.5)(u6)

    u7 = layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(u6)
    u7 = layers.concatenate([u7, conv2], axis=-1)
    u7 = layers.BatchNormalization()(u7)
    u7 = layers.Activation('relu')(u7)
    u7 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(u7)
    u7 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(u7)
    u7 = layers.Dropout(0.5)(u7)

    u8 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(u7)

    # Adjust the shape of conv1 to match the shape of u8
    conv1_adjusted = layers.Conv2D(128, (1, 1), activation='relu')(conv1)
    conv1_adjusted = layers.UpSampling2D(size=(2, 2))(conv1_adjusted)

    u8 = layers.concatenate([u8, conv1_adjusted], axis=-1)
    u8 = layers.BatchNormalization()(u8)
    u8 = layers.Activation('relu')(u8)
    u8 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(u8)
    u8 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(u8)
    u8 = layers.Dropout(0.5)(u8)

    u9 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(u8)
    u9 = layers.BatchNormalization()(u9)
    u9 = layers.Activation('relu')(u9)
    u9 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u9)
    u9 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u9)
    u9 = layers.Dropout(0.5)(u9)
    return u9

# Build Custom UNet-VGG16 Model
def build_custom_unet_vgg16_for_rgb(input_shape, num_classes=7):
    inputs = tf.keras.layers.Input(input_shape)

    """ Encoder """
    s3, s2, s1 = custom_vgg16_encoder(inputs)

    """ Decoder (U-Net) """
    u_net_decoder_output = custom_unet_decoder(s3, s2, s1, s1)

    """ Output """
    outputs = tf.keras.layers.Conv2D(num_classes, (1, 1), activation='softmax')(u_net_decoder_output)

    model = tf.keras.models.Model(inputs, outputs, name="Custom_RGB_Brain_Tumor_Segmentation_Model")
    return model

# Create the model instance for RGB input
custom_rgb_model = build_custom_unet_vgg16_for_rgb((256, 256, 3), num_classes=7)

# Compile the model
custom_rgb_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary
custom_rgb_model.summary()
# Out:
# Model: "Custom_RGB_Brain_Tumor_Segmentation_Model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_10 (InputLayer)       [(None, 256, 256, 3)]        0         []
#
#  conv2d_207 (Conv2D)         (None, 256, 256, 64)         1792      ['input_10[0][0]']
#
#  conv2d_208 (Conv2D)         (None, 256, 256, 64)         36928     ['conv2d_207[0][0]']
#
#  max_pooling2d_36 (MaxPooli  (None, 128, 128, 64)         0         ['conv2d_208[0][0]']
#  ng2D)
#
#  conv2d_209 (Conv2D)         (None, 128, 128, 128)        73856     ['max_pooling2d_36[0][0]']
#
#  conv2d_210 (Conv2D)         (None, 128, 128, 128)        147584    ['conv2d_209[0][0]']
#
#  max_pooling2d_37 (MaxPooli  (None, 64, 64, 128)          0         ['conv2d_210[0][0]']
#  ng2D)
#
#  conv2d_211 (Conv2D)         (None, 64, 64, 256)          295168    ['max_pooling2d_37[0][0]']
#
#  conv2d_212 (Conv2D)         (None, 64, 64, 256)          590080    ['conv2d_211[0][0]']
#
#  conv2d_213 (Conv2D)         (None, 64, 64, 256)          590080    ['conv2d_212[0][0]']
#
#  max_pooling2d_38 (MaxPooli  (None, 32, 32, 256)          0         ['conv2d_213[0][0]']
#  ng2D)
#
#  conv2d_214 (Conv2D)         (None, 32, 32, 512)          1180160   ['max_pooling2d_38[0][0]']
#
#  conv2d_215 (Conv2D)         (None, 32, 32, 512)          2359808   ['conv2d_214[0][0]']
#
#  conv2d_216 (Conv2D)         (None, 32, 32, 512)          2359808   ['conv2d_215[0][0]']
#
#  max_pooling2d_39 (MaxPooli  (None, 16, 16, 512)          0         ['conv2d_216[0][0]']
#  ng2D)
#
#  conv2d_217 (Conv2D)         (None, 16, 16, 512)          2359808   ['max_pooling2d_39[0][0]']
#
#  conv2d_218 (Conv2D)         (None, 16, 16, 512)          2359808   ['conv2d_217[0][0]']
#
#  conv2d_219 (Conv2D)         (None, 16, 16, 512)          2359808   ['conv2d_218[0][0]']
#
#  conv2d_transpose_36 (Conv2  (None, 32, 32, 512)          1049088   ['conv2d_219[0][0]']
#  DTranspose)
#
#  concatenate_27 (Concatenat  (None, 32, 32, 1024)         0         ['conv2d_transpose_36[0][0]',
#  e)                                                                  'conv2d_216[0][0]']
#
#  batch_normalization_36 (Ba  (None, 32, 32, 1024)         4096      ['concatenate_27[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 32, 32, 1024)         0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_220 (Conv2D)         (None, 32, 32, 512)          4719104   ['activation_36[0][0]']
#
#  conv2d_221 (Conv2D)         (None, 32, 32, 512)          2359808   ['conv2d_220[0][0]']
#
#  dropout_36 (Dropout)        (None, 32, 32, 512)          0         ['conv2d_221[0][0]']
#
#  conv2d_transpose_37 (Conv2  (None, 64, 64, 256)          524544    ['dropout_36[0][0]']
#  DTranspose)
#
#  concatenate_28 (Concatenat  (None, 64, 64, 512)          0         ['conv2d_transpose_37[0][0]',
#  e)                                                                  'conv2d_213[0][0]']
#
#  batch_normalization_37 (Ba  (None, 64, 64, 512)          2048      ['concatenate_28[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 64, 64, 512)          0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  conv2d_222 (Conv2D)         (None, 64, 64, 256)          1179904   ['activation_37[0][0]']
#
#  conv2d_223 (Conv2D)         (None, 64, 64, 256)          590080    ['conv2d_222[0][0]']
#
#  dropout_37 (Dropout)        (None, 64, 64, 256)          0         ['conv2d_223[0][0]']
#
#  conv2d_224 (Conv2D)         (None, 64, 64, 128)          32896     ['conv2d_213[0][0]']
#
#  conv2d_transpose_38 (Conv2  (None, 128, 128, 128)        131200    ['dropout_37[0][0]']
#  DTranspose)
#
#  up_sampling2d_9 (UpSamplin  (None, 128, 128, 128)        0         ['conv2d_224[0][0]']
#  g2D)
#
#  concatenate_29 (Concatenat  (None, 128, 128, 256)        0         ['conv2d_transpose_38[0][0]',
#  e)                                                                  'up_sampling2d_9[0][0]']
#
#  batch_normalization_38 (Ba  (None, 128, 128, 256)        1024      ['concatenate_29[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 128, 128, 256)        0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_225 (Conv2D)         (None, 128, 128, 128)        295040    ['activation_38[0][0]']
#
#  conv2d_226 (Conv2D)         (None, 128, 128, 128)        147584    ['conv2d_225[0][0]']
#
#  dropout_38 (Dropout)        (None, 128, 128, 128)        0         ['conv2d_226[0][0]']
#
#  conv2d_transpose_39 (Conv2  (None, 256, 256, 64)         32832     ['dropout_38[0][0]']
#  DTranspose)
#
#  batch_normalization_39 (Ba  (None, 256, 256, 64)         256       ['conv2d_transpose_39[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 256, 256, 64)         0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_227 (Conv2D)         (None, 256, 256, 64)         36928     ['activation_39[0][0]']
#
#  conv2d_228 (Conv2D)         (None, 256, 256, 64)         36928     ['conv2d_227[0][0]']
#
#  dropout_39 (Dropout)        (None, 256, 256, 64)         0         ['conv2d_228[0][0]']
#
#  conv2d_229 (Conv2D)         (None, 256, 256, 7)          455       ['dropout_39[0][0]']
#
# ==================================================================================================
# Total params: 25858503 (98.64 MB)
# Trainable params: 25854791 (98.63 MB)
# Non-trainable params: 3712 (14.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# Custom Loss Function

# %%
(10)
epsilon = 1e-5
smooth = 1

def categorical_tversky_index(y_true, y_pred, alpha=0.7):
    # Get the dynamic shape
    shape = tf.shape(y_true)
    y_true = K.reshape(y_true, [-1, shape[-3], shape[-2], shape[-1]])
    y_pred = K.reshape(y_pred, [-1, shape[-3], shape[-2], shape[-1]])

    # Calculate Tversky index for each pixel and then average over all pixels
    true_positives = K.sum(y_true * y_pred, axis=[1, 2])
    false_negatives = K.sum(y_true * (1 - y_pred), axis=[1, 2])
    false_positives = K.sum((1 - y_true) * y_pred, axis=[1, 2])

    tversky_index = (true_positives + smooth) / (true_positives + alpha * false_negatives + (1 - alpha) * false_positives + smooth)
    return K.mean(tversky_index)


def focal_tversky_loss(y_true, y_pred, gamma=0.75):
    tversky_index = categorical_tversky_index(y_true, y_pred)
    return K.pow((1 - tversky_index), gamma)

# Custom loss function
def modified_categorical_crossentropy(y_true, y_pred):
    # Ensure y_true and y_pred are 4D
    y_true = K.reshape(y_true, (-1, y_true.shape[-3], y_true.shape[-2], y_true.shape[-1]))
    y_pred = K.reshape(y_pred, (-1, y_pred.shape[-3], y_pred.shape[-2], y_pred.shape[-1]))

    # Calculate categorical crossentropy for each pixel and then average
    cce = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
    return K.mean(cce) + (1 - categorical_tversky_index(y_true, y_pred))

# %% [markdown]
# Custom Scores

# %% [markdown]
# Checkpoints

# %%
(11)
# Custom loss function
def modified_categorical_crossentropy(y_true, y_pred):
    return tf.keras.losses.categorical_crossentropy(y_true, y_pred) + (1 - categorical_tversky_index(y_true, y_pred))

# Optimizer
adam = tf.keras.optimizers.Adam(learning_rate=0.001, epsilon=0.1)

# Compile the model
custom_rgb_model.compile(optimizer=adam, loss=modified_categorical_crossentropy, metrics=['accuracy'])

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)

# Define a custom callback to save the entire training history
class SaveHistoryCallback(tf.keras.callbacks.Callback):
    def __init__(self, csv_filename="training_history.csv"):
        self.epoch_history = []
        self.csv_filename = csv_filename

    def on_epoch_end(self, epoch, logs=None):
        self.epoch_history.append(logs)
        df = pd.DataFrame(self.epoch_history)
        df.to_csv(self.csv_filename, index=False)

save_history_callback = SaveHistoryCallback(csv_filename="weights_model/training_history.csv")

checkpointer = ModelCheckpoint(filepath="weights_model/brain_tumor_model_weights.hdf5",
                               verbose=1,
                               save_best_only=True,
                               restore_best_weights=True)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0.0001, factor=0.2)

# %% [markdown]
# Epochs

# %%
(12)
# Train the model with the callbacks
history = custom_rgb_model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=100,
    callbacks=[early_stopping, checkpointer, reduce_lr, save_history_callback],
    verbose=1
)

# Access the entire training history
entire_training_history = save_history_callback.epoch_history
# Out:
# Epoch 1/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6663 - accuracy: 0.4497
# Epoch 1: val_loss improved from inf to 1.22931, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 44s 44s/step - loss: 1.6663 - accuracy: 0.4497 - val_loss: 1.2293 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 2/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6624 - accuracy: 0.4526
# Epoch 2: val_loss improved from 1.22931 to 1.22899, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.6624 - accuracy: 0.4526 - val_loss: 1.2290 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 3/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6576 - accuracy: 0.4560
# Epoch 3: val_loss improved from 1.22899 to 1.22862, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.6576 - accuracy: 0.4560 - val_loss: 1.2286 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 4/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6512 - accuracy: 0.4607
# Epoch 4: val_loss improved from 1.22862 to 1.22822, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.6512 - accuracy: 0.4607 - val_loss: 1.2282 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 5/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6442 - accuracy: 0.4658
# Epoch 5: val_loss improved from 1.22822 to 1.22779, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.6442 - accuracy: 0.4658 - val_loss: 1.2278 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 6/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6383 - accuracy: 0.4701
# Epoch 6: val_loss improved from 1.22779 to 1.22732, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.6383 - accuracy: 0.4701 - val_loss: 1.2273 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 7/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6319 - accuracy: 0.4746
# Epoch 7: val_loss improved from 1.22732 to 1.22684, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.6319 - accuracy: 0.4746 - val_loss: 1.2268 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 8/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6272 - accuracy: 0.4796
# Epoch 8: val_loss improved from 1.22684 to 1.22632, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.6272 - accuracy: 0.4796 - val_loss: 1.2263 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 9/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6214 - accuracy: 0.4840
# Epoch 9: val_loss improved from 1.22632 to 1.22578, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.6214 - accuracy: 0.4840 - val_loss: 1.2258 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 10/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6153 - accuracy: 0.4889
# Epoch 10: val_loss improved from 1.22578 to 1.22521, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 40s 40s/step - loss: 1.6153 - accuracy: 0.4889 - val_loss: 1.2252 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 11/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6076 - accuracy: 0.4938
# Epoch 11: val_loss improved from 1.22521 to 1.22461, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.6076 - accuracy: 0.4938 - val_loss: 1.2246 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 12/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6025 - accuracy: 0.4984
# Epoch 12: val_loss improved from 1.22461 to 1.22399, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.6025 - accuracy: 0.4984 - val_loss: 1.2240 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 13/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5962 - accuracy: 0.5028
# Epoch 13: val_loss improved from 1.22399 to 1.22334, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.5962 - accuracy: 0.5028 - val_loss: 1.2233 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 14/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5935 - accuracy: 0.5069
# Epoch 14: val_loss improved from 1.22334 to 1.22267, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.5935 - accuracy: 0.5069 - val_loss: 1.2227 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 15/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5879 - accuracy: 0.5110
# Epoch 15: val_loss improved from 1.22267 to 1.22197, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.5879 - accuracy: 0.5110 - val_loss: 1.2220 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 16/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5835 - accuracy: 0.5146
# Epoch 16: val_loss improved from 1.22197 to 1.22125, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.5835 - accuracy: 0.5146 - val_loss: 1.2213 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 17/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5799 - accuracy: 0.5174
# Epoch 17: val_loss improved from 1.22125 to 1.22051, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.5799 - accuracy: 0.5174 - val_loss: 1.2205 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 18/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5758 - accuracy: 0.5205
# Epoch 18: val_loss improved from 1.22051 to 1.21975, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.5758 - accuracy: 0.5205 - val_loss: 1.2197 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 19/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5741 - accuracy: 0.5234
# Epoch 19: val_loss improved from 1.21975 to 1.21897, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.5741 - accuracy: 0.5234 - val_loss: 1.2190 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 20/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5714 - accuracy: 0.5253
# Epoch 20: val_loss improved from 1.21897 to 1.21818, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.5714 - accuracy: 0.5253 - val_loss: 1.2182 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 21/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5686 - accuracy: 0.5275
# Epoch 21: val_loss improved from 1.21818 to 1.21736, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.5686 - accuracy: 0.5275 - val_loss: 1.2174 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 22/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5685 - accuracy: 0.5298
# Epoch 22: val_loss improved from 1.21736 to 1.21654, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.5685 - accuracy: 0.5298 - val_loss: 1.2165 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 23/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5678 - accuracy: 0.5299
# Epoch 23: val_loss improved from 1.21654 to 1.21571, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.5678 - accuracy: 0.5299 - val_loss: 1.2157 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 24/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5673 - accuracy: 0.5308
# Epoch 24: val_loss improved from 1.21571 to 1.21487, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.5673 - accuracy: 0.5308 - val_loss: 1.2149 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 25/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5659 - accuracy: 0.5320
# Epoch 25: val_loss improved from 1.21487 to 1.21401, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.5659 - accuracy: 0.5320 - val_loss: 1.2140 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 26/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5678 - accuracy: 0.5313
# Epoch 26: val_loss improved from 1.21401 to 1.21316, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.5678 - accuracy: 0.5313 - val_loss: 1.2132 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 27/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5683 - accuracy: 0.5309
# Epoch 27: val_loss improved from 1.21316 to 1.21230, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 40s 40s/step - loss: 1.5683 - accuracy: 0.5309 - val_loss: 1.2123 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 28/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5716 - accuracy: 0.5292
# Epoch 28: val_loss improved from 1.21230 to 1.21143, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.5716 - accuracy: 0.5292 - val_loss: 1.2114 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 29/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5745 - accuracy: 0.5288
# Epoch 29: val_loss improved from 1.21143 to 1.21056, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.5745 - accuracy: 0.5288 - val_loss: 1.2106 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 30/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5775 - accuracy: 0.5269
# Epoch 30: val_loss improved from 1.21056 to 1.20968, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.5775 - accuracy: 0.5269 - val_loss: 1.2097 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 31/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5806 - accuracy: 0.5245
# Epoch 31: val_loss improved from 1.20968 to 1.20881, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.5806 - accuracy: 0.5245 - val_loss: 1.2088 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 32/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5844 - accuracy: 0.5223
# Epoch 32: val_loss improved from 1.20881 to 1.20793, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.5844 - accuracy: 0.5223 - val_loss: 1.2079 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 33/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5871 - accuracy: 0.5204
# Epoch 33: val_loss improved from 1.20793 to 1.20706, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.5871 - accuracy: 0.5204 - val_loss: 1.2071 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 34/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5938 - accuracy: 0.5167
# Epoch 34: val_loss improved from 1.20706 to 1.20619, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.5938 - accuracy: 0.5167 - val_loss: 1.2062 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 35/100
# 1/1 [==============================] - ETA: 0s - loss: 1.5982 - accuracy: 0.5133
# Epoch 35: val_loss improved from 1.20619 to 1.20531, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.5982 - accuracy: 0.5133 - val_loss: 1.2053 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 36/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6047 - accuracy: 0.5093
# Epoch 36: val_loss improved from 1.20531 to 1.20444, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.6047 - accuracy: 0.5093 - val_loss: 1.2044 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 37/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6101 - accuracy: 0.5061
# Epoch 37: val_loss improved from 1.20444 to 1.20357, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.6101 - accuracy: 0.5061 - val_loss: 1.2036 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 38/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6168 - accuracy: 0.5015
# Epoch 38: val_loss improved from 1.20357 to 1.20271, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.6168 - accuracy: 0.5015 - val_loss: 1.2027 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 39/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6226 - accuracy: 0.4970
# Epoch 39: val_loss improved from 1.20271 to 1.20185, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.6226 - accuracy: 0.4970 - val_loss: 1.2019 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 40/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6303 - accuracy: 0.4927
# Epoch 40: val_loss improved from 1.20185 to 1.20100, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.6303 - accuracy: 0.4927 - val_loss: 1.2010 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 41/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6377 - accuracy: 0.4873
# Epoch 41: val_loss improved from 1.20100 to 1.20014, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.6377 - accuracy: 0.4873 - val_loss: 1.2001 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 42/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6454 - accuracy: 0.4827
# Epoch 42: val_loss improved from 1.20014 to 1.19929, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.6454 - accuracy: 0.4827 - val_loss: 1.1993 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 43/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6525 - accuracy: 0.4772
# Epoch 43: val_loss improved from 1.19929 to 1.19844, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.6525 - accuracy: 0.4772 - val_loss: 1.1984 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 44/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6596 - accuracy: 0.4720
# Epoch 44: val_loss improved from 1.19844 to 1.19760, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.6596 - accuracy: 0.4720 - val_loss: 1.1976 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 45/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6665 - accuracy: 0.4665
# Epoch 45: val_loss improved from 1.19760 to 1.19677, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.6665 - accuracy: 0.4665 - val_loss: 1.1968 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 46/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6743 - accuracy: 0.4612
# Epoch 46: val_loss improved from 1.19677 to 1.19593, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.6743 - accuracy: 0.4612 - val_loss: 1.1959 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 47/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6819 - accuracy: 0.4553
# Epoch 47: val_loss improved from 1.19593 to 1.19508, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.6819 - accuracy: 0.4553 - val_loss: 1.1951 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 48/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6896 - accuracy: 0.4498
# Epoch 48: val_loss improved from 1.19508 to 1.19424, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.6896 - accuracy: 0.4498 - val_loss: 1.1942 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 49/100
# 1/1 [==============================] - ETA: 0s - loss: 1.6973 - accuracy: 0.4440
# Epoch 49: val_loss improved from 1.19424 to 1.19338, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.6973 - accuracy: 0.4440 - val_loss: 1.1934 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 50/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7050 - accuracy: 0.4379
# Epoch 50: val_loss improved from 1.19338 to 1.19252, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.7050 - accuracy: 0.4379 - val_loss: 1.1925 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 51/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7120 - accuracy: 0.4325
# Epoch 51: val_loss improved from 1.19252 to 1.19165, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.7120 - accuracy: 0.4325 - val_loss: 1.1916 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 52/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7190 - accuracy: 0.4262
# Epoch 52: val_loss improved from 1.19165 to 1.19077, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.7190 - accuracy: 0.4262 - val_loss: 1.1908 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7254 - accuracy: 0.4204
# Epoch 53: val_loss improved from 1.19077 to 1.18988, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.7254 - accuracy: 0.4204 - val_loss: 1.1899 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 54/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7332 - accuracy: 0.4149
# Epoch 54: val_loss improved from 1.18988 to 1.18899, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.7332 - accuracy: 0.4149 - val_loss: 1.1890 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 55/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7394 - accuracy: 0.4088
# Epoch 55: val_loss improved from 1.18899 to 1.18808, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.7394 - accuracy: 0.4088 - val_loss: 1.1881 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 56/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7444 - accuracy: 0.4038
# Epoch 56: val_loss improved from 1.18808 to 1.18717, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.7444 - accuracy: 0.4038 - val_loss: 1.1872 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 57/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7505 - accuracy: 0.3985
# Epoch 57: val_loss improved from 1.18717 to 1.18624, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.7505 - accuracy: 0.3985 - val_loss: 1.1862 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 58/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7565 - accuracy: 0.3929
# Epoch 58: val_loss improved from 1.18624 to 1.18531, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.7565 - accuracy: 0.3929 - val_loss: 1.1853 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 59/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7582 - accuracy: 0.3876
# Epoch 59: val_loss improved from 1.18531 to 1.18438, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.7582 - accuracy: 0.3876 - val_loss: 1.1844 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 60/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7629 - accuracy: 0.3817
# Epoch 60: val_loss improved from 1.18438 to 1.18344, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.7629 - accuracy: 0.3817 - val_loss: 1.1834 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 61/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7645 - accuracy: 0.3775
# Epoch 61: val_loss improved from 1.18344 to 1.18250, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.7645 - accuracy: 0.3775 - val_loss: 1.1825 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 62/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7693 - accuracy: 0.3716
# Epoch 62: val_loss improved from 1.18250 to 1.18156, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.7693 - accuracy: 0.3716 - val_loss: 1.1816 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 63/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7721 - accuracy: 0.3667
# Epoch 63: val_loss improved from 1.18156 to 1.18062, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.7721 - accuracy: 0.3667 - val_loss: 1.1806 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 64/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7714 - accuracy: 0.3625
# Epoch 64: val_loss improved from 1.18062 to 1.17970, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.7714 - accuracy: 0.3625 - val_loss: 1.1797 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 65/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7728 - accuracy: 0.3572
# Epoch 65: val_loss improved from 1.17970 to 1.17878, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.7728 - accuracy: 0.3572 - val_loss: 1.1788 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 66/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7737 - accuracy: 0.3530
# Epoch 66: val_loss improved from 1.17878 to 1.17788, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.7737 - accuracy: 0.3530 - val_loss: 1.1779 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 67/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7734 - accuracy: 0.3484
# Epoch 67: val_loss improved from 1.17788 to 1.17699, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.7734 - accuracy: 0.3484 - val_loss: 1.1770 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 68/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7725 - accuracy: 0.3438
# Epoch 68: val_loss improved from 1.17699 to 1.17611, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.7725 - accuracy: 0.3438 - val_loss: 1.1761 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 69/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7747 - accuracy: 0.3400
# Epoch 69: val_loss improved from 1.17611 to 1.17525, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.7747 - accuracy: 0.3400 - val_loss: 1.1752 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 70/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7700 - accuracy: 0.3358
# Epoch 70: val_loss improved from 1.17525 to 1.17441, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.7700 - accuracy: 0.3358 - val_loss: 1.1744 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 71/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7718 - accuracy: 0.3327
# Epoch 71: val_loss improved from 1.17441 to 1.17359, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.7718 - accuracy: 0.3327 - val_loss: 1.1736 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 72/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7652 - accuracy: 0.3289
# Epoch 72: val_loss improved from 1.17359 to 1.17286, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.7652 - accuracy: 0.3289 - val_loss: 1.1729 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 73/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7888 - accuracy: 0.3256
# Epoch 73: val_loss improved from 1.17286 to 1.17198, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.7888 - accuracy: 0.3256 - val_loss: 1.1720 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 74/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7499 - accuracy: 0.3218
# Epoch 74: val_loss improved from 1.17198 to 1.17133, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.7499 - accuracy: 0.3218 - val_loss: 1.1713 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 75/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7522 - accuracy: 0.3184
# Epoch 75: val_loss improved from 1.17133 to 1.17088, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.7522 - accuracy: 0.3184 - val_loss: 1.1709 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 76/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7739 - accuracy: 0.3163
# Epoch 76: val_loss improved from 1.17088 to 1.17046, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.7739 - accuracy: 0.3163 - val_loss: 1.1705 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 77/100
# 1/1 [==============================] - ETA: 0s - loss: 2.0569 - accuracy: 0.3117
# Epoch 77: val_loss improved from 1.17046 to 1.16849, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 2.0569 - accuracy: 0.3117 - val_loss: 1.1685 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 78/100
# 1/1 [==============================] - ETA: 0s - loss: 1.9854 - accuracy: 0.3116
# Epoch 78: val_loss improved from 1.16849 to 1.16616, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.9854 - accuracy: 0.3116 - val_loss: 1.1662 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 79/100
# 1/1 [==============================] - ETA: 0s - loss: 3.0263 - accuracy: 0.3054
# Epoch 79: val_loss improved from 1.16616 to 1.16435, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 3.0263 - accuracy: 0.3054 - val_loss: 1.1643 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 80/100
# 1/1 [==============================] - ETA: 0s - loss: 2.2900 - accuracy: 0.3089
# Epoch 80: val_loss improved from 1.16435 to 1.16260, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 2.2900 - accuracy: 0.3089 - val_loss: 1.1626 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 81/100
# 1/1 [==============================] - ETA: 0s - loss: 2.1380 - accuracy: 0.3118
# Epoch 81: val_loss improved from 1.16260 to 1.16094, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 2.1380 - accuracy: 0.3118 - val_loss: 1.1609 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 82/100
# 1/1 [==============================] - ETA: 0s - loss: 2.0776 - accuracy: 0.3133
# Epoch 82: val_loss improved from 1.16094 to 1.15936, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 2.0776 - accuracy: 0.3133 - val_loss: 1.1594 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 83/100
# 1/1 [==============================] - ETA: 0s - loss: 2.0435 - accuracy: 0.3153
# Epoch 83: val_loss improved from 1.15936 to 1.15793, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 2.0435 - accuracy: 0.3153 - val_loss: 1.1579 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 84/100
# 1/1 [==============================] - ETA: 0s - loss: 2.0130 - accuracy: 0.3168
# Epoch 84: val_loss improved from 1.15793 to 1.15670, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 2.0130 - accuracy: 0.3168 - val_loss: 1.1567 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 85/100
# 1/1 [==============================] - ETA: 0s - loss: 1.9915 - accuracy: 0.3162
# Epoch 85: val_loss improved from 1.15670 to 1.15574, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.9915 - accuracy: 0.3162 - val_loss: 1.1557 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 86/100
# 1/1 [==============================] - ETA: 0s - loss: 1.9661 - accuracy: 0.3160
# Epoch 86: val_loss improved from 1.15574 to 1.15502, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.9661 - accuracy: 0.3160 - val_loss: 1.1550 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 87/100
# 1/1 [==============================] - ETA: 0s - loss: 1.9390 - accuracy: 0.3157
# Epoch 87: val_loss improved from 1.15502 to 1.15445, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.9390 - accuracy: 0.3157 - val_loss: 1.1544 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 88/100
# 1/1 [==============================] - ETA: 0s - loss: 1.9142 - accuracy: 0.3151
# Epoch 88: val_loss improved from 1.15445 to 1.15403, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 38s 38s/step - loss: 1.9142 - accuracy: 0.3151 - val_loss: 1.1540 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 89/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8890 - accuracy: 0.3141
# Epoch 89: val_loss improved from 1.15403 to 1.15379, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.8890 - accuracy: 0.3141 - val_loss: 1.1538 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 90/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8580 - accuracy: 0.3132
# Epoch 90: val_loss improved from 1.15379 to 1.15378, saving model to weights_model\brain_tumor_model_weights.hdf5
# 1/1 [==============================] - 39s 39s/step - loss: 1.8580 - accuracy: 0.3132 - val_loss: 1.1538 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 91/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8280 - accuracy: 0.3120
# Epoch 91: val_loss did not improve from 1.15378
# 1/1 [==============================] - 38s 38s/step - loss: 1.8280 - accuracy: 0.3120 - val_loss: 1.1540 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 92/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7991 - accuracy: 0.3101
# Epoch 92: val_loss did not improve from 1.15378
# 1/1 [==============================] - 37s 37s/step - loss: 1.7991 - accuracy: 0.3101 - val_loss: 1.1543 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 93/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7872 - accuracy: 0.3075
# Epoch 93: val_loss did not improve from 1.15378
# 1/1 [==============================] - 37s 37s/step - loss: 1.7872 - accuracy: 0.3075 - val_loss: 1.1549 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 94/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7910 - accuracy: 0.3045
# Epoch 94: val_loss did not improve from 1.15378
# 1/1 [==============================] - 38s 38s/step - loss: 1.7910 - accuracy: 0.3045 - val_loss: 1.1555 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 95/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8306 - accuracy: 0.3008
# Epoch 95: val_loss did not improve from 1.15378
# 1/1 [==============================] - 37s 37s/step - loss: 1.8306 - accuracy: 0.3008 - val_loss: 1.1562 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 96/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7902 - accuracy: 0.3006
# Epoch 96: val_loss did not improve from 1.15378
# 1/1 [==============================] - 37s 37s/step - loss: 1.7902 - accuracy: 0.3006 - val_loss: 1.1570 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 97/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7745 - accuracy: 0.2991
# Epoch 97: val_loss did not improve from 1.15378
# 1/1 [==============================] - 38s 38s/step - loss: 1.7745 - accuracy: 0.2991 - val_loss: 1.1580 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 98/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7766 - accuracy: 0.2959
# Epoch 98: val_loss did not improve from 1.15378
# 1/1 [==============================] - 37s 37s/step - loss: 1.7766 - accuracy: 0.2959 - val_loss: 1.1591 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 99/100
# 1/1 [==============================] - ETA: 0s - loss: 1.8089 - accuracy: 0.2933
# Epoch 99: val_loss did not improve from 1.15378
#
# Epoch 99: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 1/1 [==============================] - 38s 38s/step - loss: 1.8089 - accuracy: 0.2933 - val_loss: 1.1601 - val_accuracy: 1.0000 - lr: 0.0010
# Epoch 100/100
# 1/1 [==============================] - ETA: 0s - loss: 1.7649 - accuracy: 0.2914
# Epoch 100: val_loss did not improve from 1.15378
# 1/1 [==============================] - 37s 37s/step - loss: 1.7649 - accuracy: 0.2914 - val_loss: 1.1635 - val_accuracy: 1.0000 - lr: 2.0000e-04
